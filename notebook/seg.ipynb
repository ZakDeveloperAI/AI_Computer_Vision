# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# c:\Users\Zak\Desktop\yolo11

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.91  Python-3.11.7 torch-2.3.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3070, 8192MiB)
# Setup complete  (12 CPUs, 15.9 GB RAM, 701.7/952.8 GB disk)

# %%
import os


# Create the directory

# Install the Roboflow package
# %pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="uDBnXyemv6NfkmJd9sJy")
project = rf.workspace("harsh-xfhrz").project("acne-wrinkles-segmentation")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
#
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Acne-Wrinkles-Segmentation-2 in yolov11:: 100%|██████████| 14774/14774 [00:11<00:00, 1243.60it/s]

# %%
# Define the path to the data.yaml file
data_yaml_path = f"{dataset.location}/data.yaml"

# Read the content of the file
with open(data_yaml_path, 'r') as file:
    lines = file.readlines()

# Remove the last three lines
lines = lines[:-3]

# Write the modified content back to the file
with open(data_yaml_path, 'w') as file:
    file.writelines(lines)

# Append new lines to the file
with open(data_yaml_path, 'a') as file:
    file.write('test: ../test/images\n')
    file.write('train: ../train/images\n')
    file.write('val: ../valid/images\n')

# %%
import os
from IPython import get_ipython



# Run the YOLO training command
get_ipython().system(f'yolo task=segment mode=train model=yolo11n-seg.pt data={dataset.location}/data.yaml epochs=10')
# Out:
# New https://pypi.org/project/ultralytics/8.3.93 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.91 🚀 Python-3.11.7 torch-2.3.0+cu118 CUDA:0 (NVIDIA GeForce RTX 3070, 8192MiB)
# ...
